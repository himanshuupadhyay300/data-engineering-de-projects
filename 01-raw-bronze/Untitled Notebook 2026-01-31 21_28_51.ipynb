-- %%
%python
import pandas as pd
df9_01 = pd.read_csv("/Workspace/Users/himanshuupadhyay300@gmail.com/Input_Data_source/(Clone) SampleEmployee.csv")
df9_02 = pd.read_csv("/Workspace/Users/himanshuupadhyay300@gmail.com/Input_Data_source/SampleEmployee.csv")

-- %%
create catalog if not exists sparksql_raw_git;
create schema if not exists sparksql_raw_git.default;

drop table if exists sparksql_raw_git.default.df9_01;
drop table if exists sparksql_raw_git.default.df9_02;

create table if not exists sparksql_raw_git.default.df9_01;
create table if not exists sparksql_raw_git.default.df9_02;
